# %%
import numpy as np

# %%
class Node:
    def __init__(self):
        self.parent = None
        self.children = []

    def adopt(self, child):
        self.children.append(child)
        child.parent = self

# %%
class LazyWrightFisher:
    def __init__(self, N):
        self.N = N
        self.nodes = dict()

    def node(self, t, i):
        if (t, i) not in self.nodes:
            self.nodes[(t, i)] = Node()
        return self.nodes[(t, i)]
    
    def parent(self, t, i):
        node = self.node(t, i)
        if node.parent is not None:
            return node.parent
        p = np.random.randint(0, self.N)
        parent_node = self.node(t-1, p)
        parent_node.adopt(node)
        return parent_node

# %%
# test LazyWrightFisher
N = 10
LWF = LazyWrightFisher(N)
for t in range(10):
    for i in range(N):
        print(LWF.parent(t, i))
    print()
# Out:
# Node()[Node()[]]
# Node()[Node()[]]
# Node()[Node()[]]
# Node()[Node()[]]
# Node()[Node()[]]
# Node()[Node()[]]
# Node()[Node()[], Node()[]]
# Node()[Node()[], Node()[]]
# Node()[Node()[]]
# Node()[Node()[]]
#
# Node()[Node()[]]
# Node()[Node()[], Node()[]]
# Node()[Node()[]]
# Node()[Node()[], Node()[], Node()[]]
# Node()[Node()[]]
# Node()[Node()[]]
# Node()[Node()[], Node()[]]
# Node()[Node()[]]
# Node()[Node()[], Node()[]]
# Node()[Node()[], Node()[], Node()[]]
#
# Node()[Node()[]]
# Node()[Node()[]]
# Node()[Node()[]]
# Node()[Node()[], Node()[]]
# Node()[Node()[], Node()[]]
# Node()[Node()[]]
# Node()[Node()[], Node()[], Node()[]]
# Node()[Node()[], Node()[], Node()[], Node()[]]
# Node()[Node()[]]
# Node()[Node()[]]
#
# Node()[Node()[]]
# Node()[Node()[]]
# Node()[Node()[], Node()[]]
# Node()[Node()[]]
# Node()[Node()[]]
# Node()[Node()[]]
# Node()[Node()[], Node()[]]
# Node()[Node()[], Node()[]]
# Node()[Node()[]]
# Node()[Node()[]]
#
# Node()[Node()[]]
# Node()[Node()[]]
# ...
